# %%
### Task 1: Printing a Message
print('Hello, everyone! I am learning Python. 😄')
# Out:
# Hello, everyone! I am learning Python. 😄

# %%
#Task 2: Declaring Variables

name = "Akhlas"
age = 26
favoriteanimal = "Goat"

print("Name:", name)
print("Age:", age)
print("Favorite Animal:", favoriteanimal)
# Out:
# Name: Akhlas
# Age: 26
# Favorite Animal: Goat

# %%
#Task 3: Combining Variables in a Message

print('My name is AKHLAS, I am 26 years old, and I love Goats!')
# Out:
# My name is AKHLAS, I am 26 years old, and I love Goats!

# %%
#Task 4: Playing with Different Data Types

movie = "365"
birthyear = 26
priceofsnack = "50"

print("Favorite Movie:", movie)
print("Birth Year:", birthyear)
print("rice of Snack:", priceofsnack)
# Out:
# Favorite Movie: 365
# Birth Year: 26
# rice of Snack: 50

# %%
#Task 5: Your Favorite Hobby

hobby = "Reading Books"

print("My favorite hobby is:", hobby)
# Out:
# My favorite hobby is: Reading Books

# %%
#Extra Challenge

a = 3
b = 4
c = a+b
print('a', a)
print('b', b)
print(c)
# Out:
# a 3
# b 4
# 7
